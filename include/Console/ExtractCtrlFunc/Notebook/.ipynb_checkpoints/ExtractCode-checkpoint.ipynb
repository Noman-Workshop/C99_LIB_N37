# %%
import sys
sys.path = ["/media/anonyman637/CoreProgramming/CProjects/Official/include/Console/ExtractCtrlFunc/pythonVenv/Linux/offCtrlFuncExtrcVenv/lib/python3.6",
        "/media/anonyman637/CoreProgramming/CProjects/Official/include/Console/ExtractCtrlFunc/pythonVenv/Linux/offCtrlFuncExtrcVenv/lib/python3.6/distutils",
        "/media/anonyman637/CoreProgramming/CProjects/Official/include/Console/ExtractCtrlFunc/pythonVenv/Linux/offCtrlFuncExtrcVenv/lib/python3.6/site-packages",
        "/media/anonyman637/CoreProgramming/CProjects/Official/include/Console/ExtractCtrlFunc/pythonVenv/Linux/offCtrlFuncExtrcVenv/lib/python3.6/__pycache__"
        ]
import PyPDF2

# %% [markdown]
# ## Reading Control Functions from ECMA-48 Std

# %%
standardFile = open('Ecma-048.pdf', 'rb')

# %%
standardPdf = PyPDF2.PdfFileReader(standardFile)
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
standardPdf.numPages
# Out:
# 108

# %% [markdown]
# ### Regex for formating text

# %%
import re

# %%
controlRegex = re.compile(r'8.3.\d+')

# %%
pageRegex = re.compile(r'- \d+ -')

# %%
text = ""

# %%
for pg in range(46, 89):
    text += standardPdf.getPage(pg).extractText()

# %% [markdown]
# #### Ommiting Page Numbers

# %%
text = re.sub(pageRegex, "", text)

# %% [markdown]
# #### Creating List of Control Functions

# %%
controlFuncRaw = controlRegex.split(text)

# %% [markdown]
# #### Eliminating Juncs

# %%
controlFuncRaw = controlFuncRaw[14:]

# %%
controlFuncRaw[161] = controlFuncRaw[161][:198]

# %%
len(controlFuncRaw)
# Out:
# 162

# %% [markdown]
# #### More Text Formatting

# %%
for i in range(len(controlFuncRaw)):
    controlFuncRaw[i] = controlFuncRaw[i].strip()

# %% [markdown]
# #### Getting Syntax and Documentation

# %%
# https://regex101.com/r/oWa5tj/2
parseRegex = re.compile(r'''
(.*)                    # Matching the Code
\s+\-\s+                
(.*)                    # Full name
\s+Notation:\s+\(       
(.*)                    # Notation
\)\s+Representation:\s+ 
(.*\/\d\d)              # Representation
\s+                     
(.*Parameter\sdefault\svalues?    # Parameter Info
\:\s?
(.*\=\s?\d+))?          # Defualt Parameter Substitution
(.*)                    # Documentation
''', re.VERBOSE)

# %%
print(controlFuncRaw[131])
# Out:
# SPI - SPACING INCREMENT Notation: (Pn1;Pn2) Representation: CSI Pn1;Pn2 02/00 04/07 No parameter default values.  SPI is used to establish the line spacing and the character spacing for subsequent text. The established line spacing remains in effect until the next occurrence of SPI or of SET LINE SPACING (SLS) or of SELECT LINE SPACING (SVS) in the data stream. The established character spacing remains in effect until the next occurrence of SET CHARACTER SPACING (SCS) or of SELECT CHARACTER SPACING (SHS) in the data stream, see annex C.  Pn1 specifies the line spacing  Pn2 specifies the character spacing    The unit in which the parameter values are expressed is that established by the parameter value of SELECT SIZE UNIT (SSU).

# %%
parseRegex.findall(controlFuncRaw[131])[0]
# Out:
# ('SPI',
#  'SPACING INCREMENT',
#  'Pn1;Pn2',
#  'CSI Pn1;Pn2 02/00 04/07',
#  '',
#  '',
#  'No parameter default values.  SPI is used to establish the line spacing and the character spacing for subsequent text. The established line spacing remains in effect until the next occurrence of SPI or of SET LINE SPACING (SLS) or of SELECT LINE SPACING (SVS) in the data stream. The established character spacing remains in effect until the next occurrence of SET CHARACTER SPACING (SCS) or of SELECT CHARACTER SPACING (SHS) in the data stream, see annex C.  Pn1 specifies the line spacing  Pn2 specifies the character spacing    The unit in which the parameter values are expressed is that established by the parameter value of SELECT SIZE UNIT (SSU).')

# %%
nl = "n37n"
def parseFunction(stdText):
    tokens = parseRegex.findall(stdText)
    funcTokens = tokens[0]
    
    # Group 1 contains abbreviation
    abbr = funcTokens[0].strip()
    
    # Group 2 contains full name
    name = funcTokens[1].strip()
    
    # Group 3 contains function args
    ## Get Rid of C0 and C1
    args = funcTokens[2]
    if "C0" in args or "C1" in args:
        args = []
    else:
        ### Replacing ... with blank for Ps... args
        ### Spliting Args for use
        args = args.replace("...", "").split(";")
    
    # Group 4 contains representation
    rep = funcTokens[3]
    ## Macro args will convert to strings
    for arg in args:
        rep = rep.replace(arg, "#" + arg)

    ## Parse the Hex Value Strings
    ### Find the Hex Values
    hexRegexStr = r'(\d{0,2})/(\d{0,2})'
    hexRegex = re.compile(hexRegexStr)
    hexStrs = hexRegex.findall(rep)
    ### Convert them to str
    for i in range(len(hexStrs)):
        hexStrs[i] = "\"" + chr(int(hexStrs[i][0]) * 16 + int(hexStrs[i][1])) + "\""
    
    ### Replacing Hex String with true Hex
    rep = re.sub(hexRegexStr,
                 lambda match: str(hexStrs.pop(0)),
                 rep)
    ### Taking the last representation if there are multiples (divided by 'or')
    ### Replacing ; with ";" because they should be pure strings
    ### Replacing ... with blank for Ps... args
    rep = rep.split("or")[-1].replace(";", " \";\" ").replace("...", "").strip()
    # The all args function is the first representation of all representations
    # The all default args function is the second which we will configure later
    rep = [rep]
    args = [args]
    
    
    # XXX Group 5 contains overall param info XXX
    
    # Group 6 contains default values for some parameters
    ## Multiple Definitions for default param value
    if funcTokens[5] != "":
        defParams = funcTokens[5].replace(" ", "").split(";")
        for i in range(len(defParams)):
            defParams[i] = defParams[i].split("=")[0]
            # By Definition, the absent sent will be provided default values if available
            # So we just omitted the default value args one at a time
            ## The one absent defualt representation and formatting spaces too
            rep.append(re.sub(r"\s{2,}", " ", rep[0].replace("#" + defParams[i], "")))
            ### Creating marks for def args
            defArgMarks = []
            for j in range(len(args[0])):
                if args[0][j] == defParams[i]:
                    defArgMarks.append(j)
        
            targs = args[0]
            ### Deleting the marked index
            for defArgMark in defArgMarks:
                targs = targs[:defArgMark] + targs[defArgMark + 1:]
        
            args.append(targs)
    else:
        defParams = []
    
    
    ## The all absent default representation
    if len(defParams) == len(args[0]) and len(args[0]) > 1:
        # The all default args function is the second which we are configuring now
        rep.append(rep[0])
        args.append(args[0])
        
        for defParam in defParams:
            ### Replacing default args and params with blanks and formatting spaces too
            rep[-1] = re.sub(r"\s{2,}", " ", rep[1].replace("#" + defParam, ""))
            ### marking def args
            defArgMarks = []
            for i in range(len(args[-1])):
                if args[-1][i] == defParam:
                    defArgMarks.append(i)
                    
            ### deleting marked index
            for defArgMark in defArgMarks:
                args[-1] = args[-1][:defArgMark] + args[-1][defArgMark + 1:]
    
    
    # Group 7 contains the documentation
    ## Double or more spaces are new lines
    doc = re.sub(r"\s{2,}", "\n", funcTokens[6].strip()).splitlines()
    ### Formatting the doc
    foldCol = 70
    for li in range(len(doc)):
        line = doc[li]
        if len(line) < foldCol:
            continue
        #### marks for folding cols at suitable word length
        foldMarks = [0]
        for i in range(0, len(line), foldCol):
            # Trying to get the index around 70
            lci = foldMarks[-1]
            lastWordOfCurrentLine = line.rfind(" ", lci, lci + foldCol)
            firstWordOfNextLine = line.find(" ", lci + foldCol)
            minIsLastWord = foldCol - lastWordOfCurrentLine < firstWordOfNextLine - foldCol
            foldMarks.append(lastWordOfCurrentLine if minIsLastWord else firstWordOfNextLine) 
            
#       Tolerance level of last 
        if foldMarks[-1] - foldMarks[-2] < foldCol:
            foldMarks[-1] = None
        else:
            foldMarks.append(None)
        
        foldDoc = [line[foldMarks[i]:foldMarks[i + 1]] for i in range(len(foldMarks) - 1)]
        doc[li] = (nl + " *").join(foldDoc)
    
    doc = (nl * 2 + " * ").join(doc)
    
    funcs = []
    # Creating the function
    ## Sorting, because we appended reversed earlier
    ### All Params + Default Params + All Default Params
    if len(defParams) == len(args[0]) and len(args[0]) > 1:
        rep = [rep[0]] + rep[1:-1][::-1] + [rep[-1]]
        args = [args[0]] + args[1:-1][::-1] + [args[-1]]
    
    for i in range(len(rep)):
        func = "#define "
        if len(args[i]) > 0:
            func = func + "_" * i + abbr + "(" + ", ".join(args[i]) + ")"
        elif len(defParams) > 0:
            func = func + "_" + abbr + "_"
        else:
            func = func + abbr
        func = func + " " + rep[i]
        
        ### Unique Doc for each representation of function
        customDoc = []
        #### abbr and name Info
        customDoc.append(abbr + " - " + name + nl)
        #### Args Info
        customDoc.append("@ Parameters Required: ")
        customDoc.append(", ".join(args[i]) + nl if len(args[i]) > 0 else "No Parameter Required" + nl)
        #### Doc Info
        customDoc.append("@ More Info:")
        customDoc.append(doc)
        #### Joining All
        customDoc = "/*" + nl + " * " + (nl + " * ").join(customDoc) + nl + " *" + nl + " */"
        func = customDoc + nl + func + nl*2
        funcs.append(func)
        
    return funcs

# %%
parseFunction(controlFuncRaw[0])
# Out:
# ACK is transmitted by a receiver as an affirmative response to the sendern37n *.n37nn37n * The use of ACK is defined in ISO 1745.
# ['/*n37n * ACK - ACKNOWLEDGEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * ACK is transmitted by a receiver as an affirmative response to the sendern37n *.n37nn37n * The use of ACK is defined in ISO 1745.n37n *n37n */n37n#define ACK "\x06"n37nn37n']

# %%
extracted = open("ctrlFuncCodedCharSet.h", "w", )
i = 1
problems = []
for rawFunc in controlFuncRaw:
    try:
        parsedFuncs = parseFunction(rawFunc)
    except Exception:
        problems.append(i)
        continue
    for func in parsedFuncs:
        func = repr(func)[1:-1]
        extracted.write(func)
        print(func)
    i += 1
extracted.close()
# Out:
# /*n37n * ACK - ACKNOWLEDGEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * ACK is transmitted by a receiver as an affirmative response to then37n * sender.n37nThe use of ACK is defined in ISO 1745.n37n *n37n */n37n#define ACK "\x06"n37nn37n
# /*n37n * APC - APPLICATION PROGRAM COMMANDn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * to 07/14. The control string is closed by the terminating delimitern37n * STRING TERMINATOR (ST). The interpretation of the action stringn37n * depends on the relevant application program.n37n *n37n */n37n#define APC application program use. The action string following may consist of bit combinations in the range "\x08" to "\r" and " "n37nn37n
# /*n37n * BEL - BELLn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * BEL is used when there is a need to call for attention; it may controln37n * alarm or attention devices.n37n *n37n */n37n#define BEL "\x07"n37nn37n
# /*n37n * BPH - BREAK PERMITTED HEREn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * BPH is used to indicate a point where a line break may occur when textn37n * is formatted. BPH may occur between two graphic characters, eithern37n * or both of which may be SPACE.n37n *n37n */n37n#define BPH ESC "B"n37nn37n
# /*n37n * BS - BACKSPACEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * BS causes the active data position to be moved one character positionn37n * in the data component in the direction opposite to that of then37n * implicit movement.n37nThe direction of the implicit movement dependsn37n * on the parameter value of SELECT IMPLICIT MOVEMENT DIRECTION (SIMD).n37n *n37n */n37n#define BS "\x08"n37nn37n
# /*n37n * CAN - CANCELn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CAN is used to indicate that the data preceding it in the data streamn37n * is in error. As a result, this data shall be ignored. The specificn37n * meaning of this control function shall be defined for eachn37n * application and/or between sender and recipient.n37n *n37n */n37n#define CAN "\x18"n37nn37n
# /*n37n * CBT - CURSOR BACKWARD TABULATIONn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CBT causes the active presentation position to be moved to the charactern37n * position corresponding to the n-th preceding character tabulationn37n * stop in the presentation component, according to the character path,n37n * where n equals the value of Pn.n37n *n37n */n37n#define CBT(Pn) CSI #Pn "Z"n37nn37n
# /*n37n * CBT - CURSOR BACKWARD TABULATIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CBT causes the active presentation position to be moved to the charactern37n * position corresponding to the n-th preceding character tabulationn37n * stop in the presentation component, according to the character path,n37n * where n equals the value of Pn.n37n *n37n */n37n#define _CBT_ CSI "Z"n37nn37n
# /*n37n * CCH - CANCEL CHARACTERn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CCH is used to indicate that both the preceding graphic character in then37n * data stream, (represented by one or more bit combinations) includingn37n * SPACE, and the control function CCH itself are to be ignored forn37n * further interpretation of the data stream.n37nIf the charactern37n * preceding CCH in the data stream is a control function (representedn37n * by one or more bit combinations), the effect of CCH is not definedn37n * by thisn37nStandard.n37n *n37n */n37n#define CCH ESC "T"n37nn37n
# /*n37n * CHA - CURSOR CHARACTER ABSOLUTEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CHA causes the active presentation position to be moved to charactern37n * position n in the active line in the presentation component, where nn37n * equals the value of Pn.n37n *n37n */n37n#define CHA(Pn) CSI #Pn "G"n37nn37n
# /*n37n * CHA - CURSOR CHARACTER ABSOLUTEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CHA causes the active presentation position to be moved to charactern37n * position n in the active line in the presentation component, where nn37n * equals the value of Pn.n37n *n37n */n37n#define _CHA_ CSI "G"n37nn37n
# /*n37n * CHT - CURSOR FORWARD TABULATIONn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CHT causes the active presentation position to be moved to the charactern37n * position corresponding to the n-th following character tabulationn37n * stop in the presentation component, according to the character path,n37n * where n equals the value of Pn.n37n *n37n */n37n#define CHT(Pn) CSI #Pn "I"n37nn37n
# /*n37n * CHT - CURSOR FORWARD TABULATIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CHT causes the active presentation position to be moved to the charactern37n * position corresponding to the n-th following character tabulationn37n * stop in the presentation component, according to the character path,n37n * where n equals the value of Pn.n37n *n37n */n37n#define _CHT_ CSI "I"n37nn37n
# /*n37n * CMD - CODING METHOD DELIMITERn37nn37n * @ Parameters Required: n37n * Fsn37nn37n * @ More Info:n37n * CMD is used as the delimiter of a string of data coded according ton37n * Standard ECMA-35 and to switch to a general level of control.n37nThen37n * use of CMD is not mandatory if the higher level protocol definesn37n * means of delimiting the string, for instance, by specifying then37n * length of the string.n37n *n37n */n37n#define CMD(Fs) ESC "d"n37nn37n
# /*n37n * CNL - CURSOR NEXT LINEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CNL causes the active presentation position to be moved to the firstn37n * character position of the n-th following line in the presentationn37n * component, where n equals the value of Pn.n37n *n37n */n37n#define CNL(Pn) CSI #Pn "E"n37nn37n
# /*n37n * CNL - CURSOR NEXT LINEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CNL causes the active presentation position to be moved to the firstn37n * character position of the n-th following line in the presentationn37n * component, where n equals the value of Pn.n37n *n37n */n37n#define _CNL_ CSI "E"n37nn37n
# /*n37n * CPL - CURSOR PRECEDING LINEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CPL causes the active presentation position to be moved to the firstn37n * character position of the n-th preceding line in the presentationn37n * component, where n equals the value of Pn.n37n *n37n */n37n#define CPL(Pn) CSI #Pn "F"n37nn37n
# /*n37n * CPL - CURSOR PRECEDING LINEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CPL causes the active presentation position to be moved to the firstn37n * character position of the n-th preceding line in the presentationn37n * component, where n equals the value of Pn.n37n *n37n */n37n#define _CPL_ CSI "F"n37nn37n
# /*n37n * CPR - ACTIVE POSITION REPORTn37nn37n * @ Parameters Required: n37n * Pn1, Pn2n37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, CPRn37n * is used to report the active presentation position of the sendingn37n * device as residing in the presentation component at the n-th linen37n * position according to the line progression and at the m-th charactern37n * position according to the character path, where n equals the valuen37n * of Pn1 and m equals the value of Pn2. If the DEVICE COMPONENT SELECTn37n * MODE (DCSM) is set to DATA, CPR is used to report the active datan37n * position of the sending device as residing in the data component atn37n * the n-th line position according to the line progression and at then37n * m-th character position according to the character progression,n37n * where n equals the value of Pn1 and m equals the value of Pn2. CPRn37n * may be solicited by a DEVICE STATUS REPORT (DSR) or be sent unsolicited.n37n *n37n */n37n#define CPR(Pn1, Pn2) CSI #Pn1 ";" #Pn2 "R"n37nn37n
# /*n37n * CPR - ACTIVE POSITION REPORTn37nn37n * @ Parameters Required: n37n * Pn1n37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, CPRn37n * is used to report the active presentation position of the sendingn37n * device as residing in the presentation component at the n-th linen37n * position according to the line progression and at the m-th charactern37n * position according to the character path, where n equals the valuen37n * of Pn1 and m equals the value of Pn2. If the DEVICE COMPONENT SELECTn37n * MODE (DCSM) is set to DATA, CPR is used to report the active datan37n * position of the sending device as residing in the data component atn37n * the n-th line position according to the line progression and at then37n * m-th character position according to the character progression,n37n * where n equals the value of Pn1 and m equals the value of Pn2. CPRn37n * may be solicited by a DEVICE STATUS REPORT (DSR) or be sent unsolicited.n37n *n37n */n37n#define _CPR(Pn1) CSI #Pn1 ";" "R"n37nn37n
# /*n37n * CPR - ACTIVE POSITION REPORTn37nn37n * @ Parameters Required: n37n * Pn2n37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, CPRn37n * is used to report the active presentation position of the sendingn37n * device as residing in the presentation component at the n-th linen37n * position according to the line progression and at the m-th charactern37n * position according to the character path, where n equals the valuen37n * of Pn1 and m equals the value of Pn2. If the DEVICE COMPONENT SELECTn37n * MODE (DCSM) is set to DATA, CPR is used to report the active datan37n * position of the sending device as residing in the data component atn37n * the n-th line position according to the line progression and at then37n * m-th character position according to the character progression,n37n * where n equals the value of Pn1 and m equals the value of Pn2. CPRn37n * may be solicited by a DEVICE STATUS REPORT (DSR) or be sent unsolicited.n37n *n37n */n37n#define __CPR(Pn2) CSI ";" #Pn2 "R"n37nn37n
# /*n37n * CPR - ACTIVE POSITION REPORTn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, CPRn37n * is used to report the active presentation position of the sendingn37n * device as residing in the presentation component at the n-th linen37n * position according to the line progression and at the m-th charactern37n * position according to the character path, where n equals the valuen37n * of Pn1 and m equals the value of Pn2. If the DEVICE COMPONENT SELECTn37n * MODE (DCSM) is set to DATA, CPR is used to report the active datan37n * position of the sending device as residing in the data component atn37n * the n-th line position according to the line progression and at then37n * m-th character position according to the character progression,n37n * where n equals the value of Pn1 and m equals the value of Pn2. CPRn37n * may be solicited by a DEVICE STATUS REPORT (DSR) or be sent unsolicited.n37n *n37n */n37n#define _CPR_ CSI ";" "R"n37nn37n
# /*n37n * CR - CARRIAGE RETURNn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * The effect of CR depends on the setting of the DEVICE COMPONENT SELECTn37n * MODE (DCSM) and on the parameter value of SELECT IMPLICIT MOVEMENTn37n * DIRECTION (SIMD). If the DEVICE COMPONENT SELECT MODE (DCSM) is setn37n * to PRESENTATION and with the parameter value of SIMD equal to 0, CRn37n * causes the active presentation position to be moved to the line homen37n * position of the same line in the presentation component. The linen37n * home position is established by the parameter value of SET LINE HOMEn37n * (SLH). With a parameter value of SIMD equal to 1, CR causes then37n * active presentation position to be moved to the line limit positionn37n * of the same line in the presentation component. The line limitn37n * position is established by the parameter value of SET LINE LIMITn37n * (SLL). If the DEVICE COMPONENT SELECT MODE (DCSM) is set to DATA andn37n * with a parameter value of SIMD equal to 0, CR causes the active datan37n * position to be moved to the line home position of the same line inn37n * the data component. The line home position is established by then37n * parameter value of SET LINE HOME (SLH).n37nWith a parameter value ofn37n * SIMD equal to 1, CR causes the active data position to be moved ton37n * the line limit position of the same line in the data component. Then37n * line limit position is established by the parameter value of SET LINE LIMIT (SLL).n37n *n37n */n37n#define CR "\r"n37nn37n
# /*n37n * CSI - CONTROL SEQUENCE INTRODUCERn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CSI is used as the first character of a control sequence, see 5.4.n37n *n37n */n37n#define CSI ESC "["n37nn37n
# /*n37n * CTC - CURSOR TABULATION CONTROLn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * CTC causes one or more tabulation stops to be set or cleared in then37n * presentation component, depending on the parameter values:n37n0 an37n * character tabulation stop is set at the active presentation positionn37n * 1 a line tabulation stop is set at the active line (the line thatn37n * contains the active presentation position) 2 the charactern37n * tabulation stop at the active presentation position is cleared 3 then37n * line tabulation stop at the active line is cleared 4 all charactern37n * tabulation stops in the active line are cleared 5 all charactern37n * tabulation stops are cleared 6 all line tabulation stops are clearedn37n * In the case of parameter values 0, 2 or 4 the number of linesn37n * affected depends on the setting of the TABULATION STOP MODE (TSM).n37n *n37n */n37n#define CTC(Ps) CSI #Ps "W"n37nn37n
# /*n37n * CTC - CURSOR TABULATION CONTROLn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CTC causes one or more tabulation stops to be set or cleared in then37n * presentation component, depending on the parameter values:n37n0 an37n * character tabulation stop is set at the active presentation positionn37n * 1 a line tabulation stop is set at the active line (the line thatn37n * contains the active presentation position) 2 the charactern37n * tabulation stop at the active presentation position is cleared 3 then37n * line tabulation stop at the active line is cleared 4 all charactern37n * tabulation stops in the active line are cleared 5 all charactern37n * tabulation stops are cleared 6 all line tabulation stops are clearedn37n * In the case of parameter values 0, 2 or 4 the number of linesn37n * affected depends on the setting of the TABULATION STOP MODE (TSM).n37n *n37n */n37n#define _CTC_ CSI "W"n37nn37n
# /*n37n * CUB - CURSOR LEFTn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CUB causes the active presentation position to be moved leftwards in then37n * presentation component by n character positions if the charactern37n * path is horizontal, or by n line positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define CUB(Pn) CSI #Pn "D"n37nn37n
# /*n37n * CUB - CURSOR LEFTn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CUB causes the active presentation position to be moved leftwards in then37n * presentation component by n character positions if the charactern37n * path is horizontal, or by n line positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define _CUB_ CSI "D"n37nn37n
# /*n37n * CUD - CURSOR DOWNn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CUD causes the active presentation position to be moved downwards in then37n * presentation component by n line positions if the character path isn37n * horizontal, or by n character positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define CUD(Pn) CSI #Pn "B"n37nn37n
# /*n37n * CUD - CURSOR DOWNn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CUD causes the active presentation position to be moved downwards in then37n * presentation component by n line positions if the character path isn37n * horizontal, or by n character positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define _CUD_ CSI "B"n37nn37n
# /*n37n * CUF - CURSOR RIGHTn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CUF causes the active presentation position to be moved rightwards inn37n * the presentation component by n character positions if the charactern37n * path is horizontal, or by n line positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define CUF(Pn) CSI #Pn "C"n37nn37n
# /*n37n * CUF - CURSOR RIGHTn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CUF causes the active presentation position to be moved rightwards inn37n * the presentation component by n character positions if the charactern37n * path is horizontal, or by n line positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define _CUF_ CSI "C"n37nn37n
# /*n37n * CUP - CURSOR POSITIONn37nn37n * @ Parameters Required: n37n * Pn1, Pn2n37nn37n * @ More Info:n37n * CUP causes the active presentation position to be moved in the presentationn37n * component to the n-th line position according to the linen37n * progression and to the m-th character position according to then37n * character path, where n equals the value of Pn1 and m equals the value of Pn2.n37n *n37n */n37n#define CUP(Pn1, Pn2) CSI #Pn1 ";" #Pn2 "H"n37nn37n
# /*n37n * CUP - CURSOR POSITIONn37nn37n * @ Parameters Required: n37n * Pn1n37nn37n * @ More Info:n37n * CUP causes the active presentation position to be moved in the presentationn37n * component to the n-th line position according to the linen37n * progression and to the m-th character position according to then37n * character path, where n equals the value of Pn1 and m equals the value of Pn2.n37n *n37n */n37n#define _CUP(Pn1) CSI #Pn1 ";" "H"n37nn37n
# /*n37n * CUP - CURSOR POSITIONn37nn37n * @ Parameters Required: n37n * Pn2n37nn37n * @ More Info:n37n * CUP causes the active presentation position to be moved in the presentationn37n * component to the n-th line position according to the linen37n * progression and to the m-th character position according to then37n * character path, where n equals the value of Pn1 and m equals the value of Pn2.n37n *n37n */n37n#define __CUP(Pn2) CSI ";" #Pn2 "H"n37nn37n
# /*n37n * CUP - CURSOR POSITIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CUP causes the active presentation position to be moved in the presentationn37n * component to the n-th line position according to the linen37n * progression and to the m-th character position according to then37n * character path, where n equals the value of Pn1 and m equals the value of Pn2.n37n *n37n */n37n#define _CUP_ CSI ";" "H"n37nn37n
# /*n37n * CUU - CURSOR UPn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CUU causes the active presentation position to be moved upwards in then37n * presentation component by n line positions if the character path isn37n * horizontal, or by n character positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define CUU(Pn) CSI #Pn "A"n37nn37n
# /*n37n * CUU - CURSOR UPn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CUU causes the active presentation position to be moved upwards in then37n * presentation component by n line positions if the character path isn37n * horizontal, or by n character positions if the character path isn37n * vertical, where n equals the value of Pn.n37n *n37n */n37n#define _CUU_ CSI "A"n37nn37n
# /*n37n * CVT - CURSOR LINE TABULATIONn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * CVT causes the active presentation position to be moved to the correspondingn37n * character position of the line corresponding to the n-th followingn37n * line tabulation stop in the presentation component, where n equalsn37n * the value of Pn.n37n *n37n */n37n#define CVT(Pn) CSI #Pn "Y"n37nn37n
# /*n37n * CVT - CURSOR LINE TABULATIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * CVT causes the active presentation position to be moved to the correspondingn37n * character position of the line corresponding to the n-th followingn37n * line tabulation stop in the presentation component, where n equalsn37n * the value of Pn.n37n *n37n */n37n#define _CVT_ CSI "Y"n37nn37n
# /*n37n * DA - DEVICE ATTRIBUTESn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * With a parameter value not equal to 0, DA is used to identify the devicen37n * which sends the DA. The parameter value is a device typen37n * identification code according to a register which is to ben37n * established. If the parameter value is 0, DA is used to request ann37n * identifying DA from a device.n37n *n37n */n37n#define DA(Ps) CSI #Ps "c"n37nn37n
# /*n37n * DA - DEVICE ATTRIBUTESn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * With a parameter value not equal to 0, DA is used to identify the devicen37n * which sends the DA. The parameter value is a device typen37n * identification code according to a register which is to ben37n * established. If the parameter value is 0, DA is used to request ann37n * identifying DA from a device.n37n *n37n */n37n#define _DA_ CSI "c"n37nn37n
# /*n37n * DAQ - DEFINE AREA QUALIFICATIONn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * DAQ is used to indicate that the active presentation position in then37n * presentation component is the first character position of an37n * qualified area. The last character position of the qualified area isn37n * the character position in the presentation component immediatelyn37n * preceding the first character position of the following qualifiedn37n * area.n37nThe parameter value designates the type of qualified area:n37n * 0 unprotected and unguarded 1 protected and guarded 2 graphicn37n * character input 3 numeric input 4 alphabetic input 5 input alignedn37n * on the last character position of the qualified area 6 fill withn37n * ZEROs 7 set a character tabulation stop at the active presentationn37n * position (the first character position of the qualified area) ton37n * indicate the beginning of a field 8 protected and unguarded 9 filln37n * with SPACEs 10 input aligned on the first character position of then37n * qualified area 11 the order of the character positions in the inputn37n * field is reversed, i.e. the last position in each line becomes then37n * first and vice versa; input begins at the new firstn37n * position.n37nThis control function operates independently of then37n * setting of the TABULATION STOP MODE (TSM). The character tabulationn37n * stop set by parameter value 7 applies to the active line only. NOTEn37n * The control functions for area definition (DAQ, EPA, ESA, SPA, SSA) should not be used within an SRS string or an SDS string.n37n *n37n */n37n#define DAQ(Ps) CSI #Ps "o"n37nn37n
# /*n37n * DAQ - DEFINE AREA QUALIFICATIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DAQ is used to indicate that the active presentation position in then37n * presentation component is the first character position of an37n * qualified area. The last character position of the qualified area isn37n * the character position in the presentation component immediatelyn37n * preceding the first character position of the following qualifiedn37n * area.n37nThe parameter value designates the type of qualified area:n37n * 0 unprotected and unguarded 1 protected and guarded 2 graphicn37n * character input 3 numeric input 4 alphabetic input 5 input alignedn37n * on the last character position of the qualified area 6 fill withn37n * ZEROs 7 set a character tabulation stop at the active presentationn37n * position (the first character position of the qualified area) ton37n * indicate the beginning of a field 8 protected and unguarded 9 filln37n * with SPACEs 10 input aligned on the first character position of then37n * qualified area 11 the order of the character positions in the inputn37n * field is reversed, i.e. the last position in each line becomes then37n * first and vice versa; input begins at the new firstn37n * position.n37nThis control function operates independently of then37n * setting of the TABULATION STOP MODE (TSM). The character tabulationn37n * stop set by parameter value 7 applies to the active line only. NOTEn37n * The control functions for area definition (DAQ, EPA, ESA, SPA, SSA) should not be used within an SRS string or an SDS string.n37n *n37n */n37n#define _DAQ_ CSI "o"n37nn37n
# /*n37n * DCH - DELETE CHARACTERn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, DCHn37n * causes the contents of the active presentation position and,n37n * depending on the setting of the CHARACTER EDITING MODE (HEM), then37n * contents of the n-1 preceding or following character positions to ben37n * removed from the presentation component, where n equals the value ofn37n * Pn. The resulting gap is closed by shifting the contents of then37n * adjacent character positions towards the active presentationn37n * position. At the other end of the shifted part, n charactern37n * positions are put into the erased state. The extent of the shiftedn37n * part is established by SELECT EDITING EXTENT (SEE).n37nThe effect ofn37n * DCH on the start or end of a selected area, the start or end of an37n * qualified area, or a tabulation stop in the shifted part is notn37n * defined by this Standard.n37nIf the DEVICE COMPONENT SELECT MODEn37n * (DCSM) is set to DATA, DCH causes the contents of the active datan37n * position and, depending on the setting of the CHARACTER EDITING MODEn37n * (HEM), the contents of the n-1 preceding or following charactern37n * positions to be removed from the data component, where n equals then37n * value of Pn. The resulting gap is closed by shifting the contents ofn37n * the adjacent character positions towards the active data position.n37n * At the other end of the shifted part, n character positions are put into the erased state.n37n *n37n */n37n#define DCH(Pn) CSI #Pn "P"n37nn37n
# /*n37n * DCH - DELETE CHARACTERn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, DCHn37n * causes the contents of the active presentation position and,n37n * depending on the setting of the CHARACTER EDITING MODE (HEM), then37n * contents of the n-1 preceding or following character positions to ben37n * removed from the presentation component, where n equals the value ofn37n * Pn. The resulting gap is closed by shifting the contents of then37n * adjacent character positions towards the active presentationn37n * position. At the other end of the shifted part, n charactern37n * positions are put into the erased state. The extent of the shiftedn37n * part is established by SELECT EDITING EXTENT (SEE).n37nThe effect ofn37n * DCH on the start or end of a selected area, the start or end of an37n * qualified area, or a tabulation stop in the shifted part is notn37n * defined by this Standard.n37nIf the DEVICE COMPONENT SELECT MODEn37n * (DCSM) is set to DATA, DCH causes the contents of the active datan37n * position and, depending on the setting of the CHARACTER EDITING MODEn37n * (HEM), the contents of the n-1 preceding or following charactern37n * positions to be removed from the data component, where n equals then37n * value of Pn. The resulting gap is closed by shifting the contents ofn37n * the adjacent character positions towards the active data position.n37n * At the other end of the shifted part, n character positions are put into the erased state.n37n *n37n */n37n#define _DCH_ CSI "P"n37nn37n
# /*n37n * DCS - DEVICE CONTROL STRINGn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * to 07/14. The control string is closed by the terminating delimitern37n * STRING TERMINATOR (ST).n37nThe action string represents either onen37n * or more commands for the receiving device, or one or more statusn37n * reports from the sending device. The purpose and the format of then37n * action string are specified by the most recent occurrence ofn37n * IDENTIFY DEVICE CONTROL STRING (IDCS), if any, or depend on then37n * sending and/or the receiving device.n37n *n37n */n37n#define DCS device control use. The action string following may consist of bit combinations in the range "\x08" to "\r" and " "n37nn37n
# /*n37n * DC1 - DEVICE CONTROL ONEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DC1 is primarily intended for turning on or starting an ancillary device.n37n * If it is not required for this purpose, it may be used to restore an37n * device to the basic mode of operation (see also DC2 and DC3), or anyn37n * other device control function not provided by other DCs.n37nNOTEn37n * When used for data flow control, DC1 is sometimes called "X-ON".n37n *n37n */n37n#define DC1 "\x11"n37nn37n
# /*n37n * DC2 - DEVICE CONTROL TWOn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DC2 is primarily intended for turning on or starting an ancillary device.n37n * If it is not required for this purpose, it may be used to set an37n * device to a special mode of operation (in which case DC1 is used ton37n * restore the device to the basic mode), or for any other devicen37n * control function not provided by other DCs.n37n *n37n */n37n#define DC2 "\x12"n37nn37n
# /*n37n * DC3 - DEVICE CONTROL THREEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DC3 is primarily intended for turning off or stopping an ancillary device.n37n * This function may be a secondary level stop, for example wait,n37n * pause, stand-by or halt (in which case DC1 is used to restore normaln37n * operation). If it is not required for this purpose, it may be usedn37n * for any other device control function not provided by othern37n * DCs.n37nNOTE When used for data flow control, DC3 is sometimes called "X-OFF".n37n *n37n */n37n#define DC3 "\x13"n37nn37n
# /*n37n * DC4 - DEVICE CONTROL FOURn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DC4 is primarily intended for turning off, stopping or interrupting ann37n * ancillary device. If it is not required for this purpose, it may ben37n * used for any other device control function not provided by other DCs.n37n *n37n */n37n#define DC4 "\x14"n37nn37n
# /*n37n * DL - DELETE LINEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, DLn37n * causes the contents of the active line (the line that contains then37n * active presentation position) and, depending on the setting of then37n * LINE EDITING MODE (VEM), the contents of the n-1 preceding orn37n * following lines to be removed from the presentation component, wheren37n * n equals the value of Pn. The resulting gap is closed by shiftingn37n * the contents of a number of adjacent lines towards the active line.n37n * At the other end of the shifted part, n lines are put into then37n * erased state. The active presentation position is moved to the linen37n * home position in the active line. The line home position isn37n * established by the parameter value of SET LINE HOME (SLH). If then37n * TABULATION STOP MODE (TSM) is set to SINGLE, character tabulationn37n * stops are cleared in the lines that are put into the erased state.n37n * The extent of the shifted part is established by SELECT EDITINGn37n * EXTENT (SEE).n37nAny occurrences of the start or end of a selectedn37n * area, the start or end of a qualified area, or a tabulation stop inn37n * the shifted part, are also shifted.n37nIf the DEVICE COMPONENTn37n * SELECT MODE (DCSM) is set to DATA, DL causes the contents of then37n * active line (the line that contains the active data position) and,n37n * depending on the setting of the LINE EDITING MODE (VEM), then37n * contents of the n-1 preceding or following lines to be removed fromn37n * the data component, where n equals the value of Pn. The resultingn37n * gap is closed by shifting the contents of a number of adjacent linesn37n * towards the active line. At the other end of the shifted part, nn37n * lines are put into the erased state. The active data position isn37n * moved to the line home position in the active line. The line home position is established by the parameter value of SET LINE HOME (SLH).n37n *n37n */n37n#define DL(Pn) CSI #Pn "M"n37nn37n
# /*n37n * DL - DELETE LINEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, DLn37n * causes the contents of the active line (the line that contains then37n * active presentation position) and, depending on the setting of then37n * LINE EDITING MODE (VEM), the contents of the n-1 preceding orn37n * following lines to be removed from the presentation component, wheren37n * n equals the value of Pn. The resulting gap is closed by shiftingn37n * the contents of a number of adjacent lines towards the active line.n37n * At the other end of the shifted part, n lines are put into then37n * erased state. The active presentation position is moved to the linen37n * home position in the active line. The line home position isn37n * established by the parameter value of SET LINE HOME (SLH). If then37n * TABULATION STOP MODE (TSM) is set to SINGLE, character tabulationn37n * stops are cleared in the lines that are put into the erased state.n37n * The extent of the shifted part is established by SELECT EDITINGn37n * EXTENT (SEE).n37nAny occurrences of the start or end of a selectedn37n * area, the start or end of a qualified area, or a tabulation stop inn37n * the shifted part, are also shifted.n37nIf the DEVICE COMPONENTn37n * SELECT MODE (DCSM) is set to DATA, DL causes the contents of then37n * active line (the line that contains the active data position) and,n37n * depending on the setting of the LINE EDITING MODE (VEM), then37n * contents of the n-1 preceding or following lines to be removed fromn37n * the data component, where n equals the value of Pn. The resultingn37n * gap is closed by shifting the contents of a number of adjacent linesn37n * towards the active line. At the other end of the shifted part, nn37n * lines are put into the erased state. The active data position isn37n * moved to the line home position in the active line. The line home position is established by the parameter value of SET LINE HOME (SLH).n37n *n37n */n37n#define _DL_ CSI "M"n37nn37n
# /*n37n * DLE - DATA LINK ESCAPEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DLE is used exclusively to provide supplementary transmission controln37n * functions.n37nThe use of DLE is defined in ISO 1745.n37n *n37n */n37n#define DLE "\x10"n37nn37n
# /*n37n * DMI - DISABLE MANUAL INPUTn37nn37n * @ Parameters Required: n37n * Fsn37nn37n * @ More Info:n37n * DMI causes the manual input facilities of a device to be disabled.n37n *n37n */n37n#define DMI(Fs) ESC "`"n37nn37n
# /*n37n * DSR - DEVICE STATUS REPORTn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * DSR is used either to report the status of the sending device or ton37n * request a status report from the receiving device, depending on then37n * parameter values:n37n0 ready, no malfunction detected 1 busy,n37n * another DSR must be requested later 2 busy, another DSR will be sentn37n * later 3 some malfunction detected, another DSR must be requestedn37n * later 4 some malfunction detected, another DSR will be sent later 5n37n * a DSR is requested 6 a report of the active presentation position orn37n * of the active data position in the form of ACTIVE POSITION REPORTn37n * (CPR) is requestedn37nDSR with parameter value 0, 1, 2, 3 or 4 mayn37n * be sent either unsolicited or as a response to a request such as an37n * DSR with a parameter value 5 or MESSAGE WAITING (MW).n37n *n37n */n37n#define DSR(Ps) CSI #Ps "n"n37nn37n
# /*n37n * DSR - DEVICE STATUS REPORTn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * DSR is used either to report the status of the sending device or ton37n * request a status report from the receiving device, depending on then37n * parameter values:n37n0 ready, no malfunction detected 1 busy,n37n * another DSR must be requested later 2 busy, another DSR will be sentn37n * later 3 some malfunction detected, another DSR must be requestedn37n * later 4 some malfunction detected, another DSR will be sent later 5n37n * a DSR is requested 6 a report of the active presentation position orn37n * of the active data position in the form of ACTIVE POSITION REPORTn37n * (CPR) is requestedn37nDSR with parameter value 0, 1, 2, 3 or 4 mayn37n * be sent either unsolicited or as a response to a request such as an37n * DSR with a parameter value 5 or MESSAGE WAITING (MW).n37n *n37n */n37n#define _DSR_ CSI "n"n37nn37n
# /*n37n * DTA - DIMENSION TEXT AREAn37nn37n * @ Parameters Required: n37n * Pn1, Pn2n37nn37n * @ More Info:n37n * No parameter default value.n37nDTA is used to establish the dimensionsn37n * of the text area for subsequent pages.n37nThe established dimensionsn37n * remain in effect until the next occurrence of DTA in the datan37n * stream.n37nPn1 specifies the dimension in the directionn37n * perpendicular to the line orientation Pn2 specifies the dimension inn37n * the direction parallel to the line orientation The unit in which then37n * parameter value is expressed is that established by the parametern37n * value of SELECT SIZE UNIT (SSU).n37n *n37n */n37n#define DTA(Pn1, Pn2) CSI #Pn1 ";" #Pn2 " " "T"n37nn37n
# /*n37n * EA - ERASE IN AREAn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, EAn37n * causes some or all character positions in the active qualified arean37n * (the qualified area in the presentation component which contains then37n * active presentation position) to be put into the erased state,n37n * depending on the parameter values:n37n0 the active presentationn37n * position and the character positions up to the end of the qualifiedn37n * area are put into the erased state 1 the character positions fromn37n * the beginning of the qualified area up to and including the activen37n * presentation position are put into the erased state 2 all charactern37n * positions of the qualified area are put into the erased staten37nIfn37n * the DEVICE COMPONENT SELECT MODE (DCSM) is set to DATA, EA causesn37n * some or all character positions in the active qualified area (then37n * qualified area in the data component which contains the active datan37n * position) to be put into the erased state, depending on then37n * parameter values: 0 the active data position and the charactern37n * positions up to the end of the qualified area are put into then37n * erased staten37n1 the character positions from the beginning of then37n * qualified area up to and including the active data position are putn37n * into the erased state 2 all character positions of the qualifiedn37n * area are put into the erased state Whether the character positionsn37n * of protected areas are put into the erased state, or the charactern37n * positions of unprotected areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define EA(Ps) CSI #Ps "O"n37nn37n
# /*n37n * EA - ERASE IN AREAn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, EAn37n * causes some or all character positions in the active qualified arean37n * (the qualified area in the presentation component which contains then37n * active presentation position) to be put into the erased state,n37n * depending on the parameter values:n37n0 the active presentationn37n * position and the character positions up to the end of the qualifiedn37n * area are put into the erased state 1 the character positions fromn37n * the beginning of the qualified area up to and including the activen37n * presentation position are put into the erased state 2 all charactern37n * positions of the qualified area are put into the erased staten37nIfn37n * the DEVICE COMPONENT SELECT MODE (DCSM) is set to DATA, EA causesn37n * some or all character positions in the active qualified area (then37n * qualified area in the data component which contains the active datan37n * position) to be put into the erased state, depending on then37n * parameter values: 0 the active data position and the charactern37n * positions up to the end of the qualified area are put into then37n * erased staten37n1 the character positions from the beginning of then37n * qualified area up to and including the active data position are putn37n * into the erased state 2 all character positions of the qualifiedn37n * area are put into the erased state Whether the character positionsn37n * of protected areas are put into the erased state, or the charactern37n * positions of unprotected areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define _EA_ CSI "O"n37nn37n
# /*n37n * ECH - ERASE CHARACTERn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, ECHn37n * causes the active presentation position and the n-1 followingn37n * character positions in the presentation component to be put into then37n * erased state, where n equals the value of Pn.n37nIf the DEVICEn37n * COMPONENT SELECT MODE (DCSM) is set to DATA, ECH causes the activen37n * data position and the n-1 following character positions in the datan37n * component to be put into the erased state, where n equals the valuen37n * of Pn. Whether the character positions of protected areas are putn37n * into the erased state, or the character positions of unprotectedn37n * areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define ECH(Pn) CSI #Pn "X"n37nn37n
# /*n37n * ECH - ERASE CHARACTERn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, ECHn37n * causes the active presentation position and the n-1 followingn37n * character positions in the presentation component to be put into then37n * erased state, where n equals the value of Pn.n37nIf the DEVICEn37n * COMPONENT SELECT MODE (DCSM) is set to DATA, ECH causes the activen37n * data position and the n-1 following character positions in the datan37n * component to be put into the erased state, where n equals the valuen37n * of Pn. Whether the character positions of protected areas are putn37n * into the erased state, or the character positions of unprotectedn37n * areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define _ECH_ CSI "X"n37nn37n
# /*n37n * ED - ERASE IN PAGEn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, EDn37n * causes some or all character positions of the active page (the pagen37n * which contains the active presentation position in the presentationn37n * component) to be put into the erased state, depending on then37n * parameter values:n37n0 the active presentation position and then37n * character positions up to the end of the page are put into then37n * erased state 1 the character positions from the beginning of then37n * page up to and including the active presentation position are putn37n * into the erased state 2 all character positions of the page are putn37n * into the erased staten37nIf the DEVICE COMPONENT SELECT MODE (DCSM)n37n * is set to DATA, ED causes some or all character positions of then37n * active page (the page which contains the active data position in then37n * data component) to be put into the erased state, depending on then37n * parameter values: 0 the active data position and the charactern37n * positions up to the end of the page are put into the erased state 1n37n * the character positions from the beginning of the page up to andn37n * including the active data position are put into the erased state 2n37n * all character positions of the page are put into the erased staten37n * Whether the character positions of protected areas are put into then37n * erased state, or the character positions of unprotected areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define ED(Ps) CSI #Ps "J"n37nn37n
# /*n37n * ED - ERASE IN PAGEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * If the DEVICE COMPONENT SELECT MODE (DCSM) is set to PRESENTATION, EDn37n * causes some or all character positions of the active page (the pagen37n * which contains the active presentation position in the presentationn37n * component) to be put into the erased state, depending on then37n * parameter values:n37n0 the active presentation position and then37n * character positions up to the end of the page are put into then37n * erased state 1 the character positions from the beginning of then37n * page up to and including the active presentation position are putn37n * into the erased state 2 all character positions of the page are putn37n * into the erased staten37nIf the DEVICE COMPONENT SELECT MODE (DCSM)n37n * is set to DATA, ED causes some or all character positions of then37n * active page (the page which contains the active data position in then37n * data component) to be put into the erased state, depending on then37n * parameter values: 0 the active data position and the charactern37n * positions up to the end of the page are put into the erased state 1n37n * the character positions from the beginning of the page up to andn37n * including the active data position are put into the erased state 2n37n * all character positions of the page are put into the erased staten37n * Whether the character positions of protected areas are put into then37n * erased state, or the character positions of unprotected areas only, depends on the setting of the ERASURE MODE (ERM).n37n *n37n */n37n#define _ED_ CSI "J"n37nn37n
# ...
# /*n37n * STAB - SELECTIVE TABULATIONn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * No parameter default value.n37nSTAB causes subsequent text in then37n * presentation component to be aligned according to the position andn37n * the properties of a tabulation stop which is selected from a listn37n * according to the value of the parameter Ps.n37nThe use of thisn37n * control function and means of specifying a list of tabulation stopsn37n * to be referenced by the control function are specified in othern37n * standards, for example ISO 8613-6.n37n *n37n */n37n#define STAB(Ps) CSI #Ps " " "^"n37nn37n
# /*n37n * STS - SET TRANSMIT STATEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * STS is used to establish the transmit state in the receiving device. Inn37n * this state the transmission of data from the device isn37n * possible.n37nThe actual initiation of transmission of data isn37n * performed by a data communication or input/output interface controln37n * procedure which is outside the scope of this Standard.n37nThen37n * transmit state is established either by STS appearing in then37n * received data stream or by the operation of an appropriate key on a keyboard.n37n *n37n */n37n#define STS ESC "S"n37nn37n
# /*n37n * STX - START OF TEXTn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * STX is used to indicate the beginning of a text and the end of an37n * heading.n37nThe use of STX is defined in ISO 1745.n37n *n37n */n37n#define STX "\x02"n37nn37n
# /*n37n * SU - SCROLL UPn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * SU causes the data in the presentation component to be moved by n linen37n * positions if the line orientation is horizontal, or by n charactern37n * positions if the line orientation is vertical, such that the datan37n * appear to move up; where n equals the value of Pn.n37nThe activen37n * presentation position is not affected by this control function.n37n *n37n */n37n#define SU(Pn) CSI #Pn "S"n37nn37n
# /*n37n * SU - SCROLL UPn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * SU causes the data in the presentation component to be moved by n linen37n * positions if the line orientation is horizontal, or by n charactern37n * positions if the line orientation is vertical, such that the datan37n * appear to move up; where n equals the value of Pn.n37nThe activen37n * presentation position is not affected by this control function.n37n *n37n */n37n#define _SU_ CSI "S"n37nn37n
# /*n37n * SUB - SUBSTITUTEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * SUB is used in the place of a character that has been found to be invalidn37n * or in error. SUB is intended to be introduced by automatic means.n37n *n37n */n37n#define SUB "\x1a"n37nn37n
# /*n37n * SVS - SELECT LINE SPACINGn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * SVS is used to establish the line spacing for subsequent text. Then37n * established spacing remains in effect until the next occurrence ofn37n * SVS or of SET LINE SPACING (SLS) or of SPACING INCREMENT (SPI) inn37n * the data stream. The parameter values are:n37n0 6 lines per 25,4n37n * mmn37n1 4 lines per 25,4 mmn37n2 3 lines per 25,4 mmn37n3 12 linesn37n * per 25,4 mmn37n4 8 lines per 25,4 mmn37n5 6 lines per 30,0 mmn37n6 4n37n * lines per 30,0 mmn37n7 3 lines per 30,0 mmn37n8 12 lines per 30,0n37n * mmn37n9 2 lines per 25,4 mmn37n *n37n */n37n#define SVS(Ps) CSI #Ps " " "L"n37nn37n
# /*n37n * SVS - SELECT LINE SPACINGn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * SVS is used to establish the line spacing for subsequent text. Then37n * established spacing remains in effect until the next occurrence ofn37n * SVS or of SET LINE SPACING (SLS) or of SPACING INCREMENT (SPI) inn37n * the data stream. The parameter values are:n37n0 6 lines per 25,4n37n * mmn37n1 4 lines per 25,4 mmn37n2 3 lines per 25,4 mmn37n3 12 linesn37n * per 25,4 mmn37n4 8 lines per 25,4 mmn37n5 6 lines per 30,0 mmn37n6 4n37n * lines per 30,0 mmn37n7 3 lines per 30,0 mmn37n8 12 lines per 30,0n37n * mmn37n9 2 lines per 25,4 mmn37n *n37n */n37n#define _SVS_ CSI " " "L"n37nn37n
# /*n37n * SYN - SYNCHRONOUS IDLEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * SYN is used by a synchronous transmission system in the absence of anyn37n * other character (idle condition) to provide a signal from whichn37n * synchronism may be achieved or retained between data terminaln37n * equipment.n37nThe use of SYN is defined in ISO 1745.n37n *n37n */n37n#define SYN "\x16"n37nn37n
# /*n37n * TAC - TABULATION ALIGNED CENTREDn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * No parameter default value.n37nTAC causes a character tabulation stopn37n * calling for centring to be set at character position n in the activen37n * line (the line that contains the active presentation position) andn37n * lines of subsequent text in the presentation component, where nn37n * equals the value of Pn. TAC causes the replacement of any tabulationn37n * stop previously set at that character position, but does not affectn37n * other tabulation stops.n37nA text string centred upon a tabulationn37n * stop set by TAC will be positioned so that the (trailing edge ofn37n * the) first graphic character and the (leading edge of the) lastn37n * graphic character are at approximately equal distances from the tabulation stop.n37n *n37n */n37n#define TAC(Pn) CSI #Pn " " "b"n37nn37n
# /*n37n * TALE - TABULATION ALIGNED LEADING EDGEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * No parameter default value.n37nTALE causes a character tabulation stopn37n * calling for leading edge alignment to be set at character position nn37n * in the active line (the line that contains the active presentationn37n * position) and lines of subsequent text in the presentationn37n * component, where n equals the value of Pn. TALE causes then37n * replacement of any tabulation stop previously set at that charactern37n * position, but does not affect other tabulation stops.n37nA textn37n * string aligned with a tabulation stop set by TALE will be positionedn37n * so that the (leading edge of the) last graphic character of the string is placed at the tabulation stop.n37n *n37n */n37n#define TALE(Pn) CSI #Pn " " "a"n37nn37n
# /*n37n * TATE - TABULATION ALIGNED TRAILING EDGEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * No parameter default value.n37nTATE causes a character tabulation stopn37n * calling for trailing edge alignment to be set at character positionn37n * n in the active line (the line that contains the active presentationn37n * position) and lines of subsequent text in the presentationn37n * component, where n equals the value of Pn. TATE causes then37n * replacement of any tabulation stop previously set at that charactern37n * position, but does not affect other tabulation stops.n37nA textn37n * string aligned with a tabulation stop set by TATE will be positionedn37n * so that the (trailing edge of the) first graphic character of then37n * string is placed at the tabulation stop.n37n *n37n */n37n#define TATE(Pn) CSI #Pn " " "`"n37nn37n
# /*n37n * TBC - TABULATION CLEARn37nn37n * @ Parameters Required: n37n * Psn37nn37n * @ More Info:n37n * TBC causes one or more tabulation stops in the presentation componentn37n * to be cleared, depending on the parameter value:n37n0 the charactern37n * tabulation stop at the active presentation position is clearedn37n1n37n * the line tabulation stop at the active line is clearedn37n2 alln37n * character tabulation stops in the active line are clearedn37n3 alln37n * character tabulation stops are clearedn37n4 all line tabulationn37n * stops are clearedn37n5 all tabulation stops are cleared In the casen37n * of parameter value 0 or 2 the number of lines affected depends onn37n * the setting of the TABULATION STOP MODE (TSM)n37n *n37n */n37n#define TBC(Ps) CSI #Ps "g"n37nn37n
# /*n37n * TBC - TABULATION CLEARn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * TBC causes one or more tabulation stops in the presentation componentn37n * to be cleared, depending on the parameter value:n37n0 the charactern37n * tabulation stop at the active presentation position is clearedn37n1n37n * the line tabulation stop at the active line is clearedn37n2 alln37n * character tabulation stops in the active line are clearedn37n3 alln37n * character tabulation stops are clearedn37n4 all line tabulationn37n * stops are clearedn37n5 all tabulation stops are cleared In the casen37n * of parameter value 0 or 2 the number of lines affected depends onn37n * the setting of the TABULATION STOP MODE (TSM)n37n *n37n */n37n#define _TBC_ CSI "g"n37nn37n
# /*n37n * TCC - TABULATION CENTRED ON CHARACTERn37nn37n * @ Parameters Required: n37n * Pn1, Pn2n37nn37n * @ More Info:n37n * TCC causes a character tabulation stop calling for alignment of a targetn37n * graphic character to be set at character position n in the activen37n * line (the line that contains the active presentation position) andn37n * lines of subsequent text in the presentation component, where nn37n * equals the value of Pn1, and the target character about whichn37n * centring is to be performed is specified by Pn2. TCC causes then37n * replacement of any tabulation stop previously set at that charactern37n * position, but does not affect other tabulation stops.n37nThen37n * positioning of a text string aligned with a tabulation stop set byn37n * TCC will be determined by the first occurrence in the string of then37n * target graphic character; that character will be centred upon then37n * tabulation stop. If the target character does not occur within then37n * string, then the trailing edge of the first character of the stringn37n * will be positioned at the tabulation stop.n37nThe value of Pn2n37n * indicates the code table position (binary value) of the targetn37n * character in the currently invoked code. For a 7-bit code, then37n * permissible range of values is 32 to 127; for an 8-bit code, the permissible range of values is 32 to 127 and 160 to 255.n37n *n37n */n37n#define TCC(Pn1, Pn2) CSI #Pn1 ";" #Pn2 " " "c"n37nn37n
# /*n37n * TCC - TABULATION CENTRED ON CHARACTERn37nn37n * @ Parameters Required: n37n * Pn1n37nn37n * @ More Info:n37n * TCC causes a character tabulation stop calling for alignment of a targetn37n * graphic character to be set at character position n in the activen37n * line (the line that contains the active presentation position) andn37n * lines of subsequent text in the presentation component, where nn37n * equals the value of Pn1, and the target character about whichn37n * centring is to be performed is specified by Pn2. TCC causes then37n * replacement of any tabulation stop previously set at that charactern37n * position, but does not affect other tabulation stops.n37nThen37n * positioning of a text string aligned with a tabulation stop set byn37n * TCC will be determined by the first occurrence in the string of then37n * target graphic character; that character will be centred upon then37n * tabulation stop. If the target character does not occur within then37n * string, then the trailing edge of the first character of the stringn37n * will be positioned at the tabulation stop.n37nThe value of Pn2n37n * indicates the code table position (binary value) of the targetn37n * character in the currently invoked code. For a 7-bit code, then37n * permissible range of values is 32 to 127; for an 8-bit code, the permissible range of values is 32 to 127 and 160 to 255.n37n *n37n */n37n#define _TCC(Pn1) CSI #Pn1 ";" " " "c"n37nn37n
# /*n37n * TSR - TABULATION STOP REMOVEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * No parameter default value.n37nTSR causes any character tabulation stopn37n * at character position n in the active line (the line that containsn37n * the active presentation position) and lines of subsequent text inn37n * the presentation component to be cleared, but does not affect othern37n * tabulation stops. n equals the value of Pn.n37n *n37n */n37n#define TSR(Pn) CSI #Pn " " "d"n37nn37n
# /*n37n * TSS - THIN SPACE SPECIFICATIONn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * No parameter default value.n37nTSS is used to establish the width of an37n * thin space for subsequent text. The established width remains inn37n * effect until the next occurrence of TSS in the data stream, seen37n * annex C.n37nPn specifies the width of the thin space.n37nThe unit inn37n * which the parameter value is expressed is that established by then37n * parameter value of SELECT SIZE UNIT (SSU).n37n *n37n */n37n#define TSS(Pn) CSI #Pn " " "E"n37nn37n
# /*n37n * VPA - LINE POSITION ABSOLUTEn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * VPA causes the active data position to be moved to line position n inn37n * the data component in a direction parallel to the line progression,n37n * where n equals the value of Pn.n37n *n37n */n37n#define VPA(Pn) CSI #Pn "d"n37nn37n
# /*n37n * VPA - LINE POSITION ABSOLUTEn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * VPA causes the active data position to be moved to line position n inn37n * the data component in a direction parallel to the line progression,n37n * where n equals the value of Pn.n37n *n37n */n37n#define _VPA_ CSI "d"n37nn37n
# /*n37n * VPB - LINE POSITION BACKWARDn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * VPB causes the active data position to be moved by n line positions inn37n * the data component in a direction opposite to that of the linen37n * progression, where n equals the value of Pn.n37n *n37n */n37n#define VPB(Pn) CSI #Pn "k"n37nn37n
# /*n37n * VPB - LINE POSITION BACKWARDn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * VPB causes the active data position to be moved by n line positions inn37n * the data component in a direction opposite to that of the linen37n * progression, where n equals the value of Pn.n37n *n37n */n37n#define _VPB_ CSI "k"n37nn37n
# /*n37n * VPR - LINE POSITION FORWARDn37nn37n * @ Parameters Required: n37n * Pnn37nn37n * @ More Info:n37n * VPR causes the active data position to be moved by n line positions inn37n * the data component in a direction parallel to the line progression,n37n * where n equals the value of Pn.n37n *n37n */n37n#define VPR(Pn) CSI #Pn "e"n37nn37n
# /*n37n * VPR - LINE POSITION FORWARDn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * VPR causes the active data position to be moved by n line positions inn37n * the data component in a direction parallel to the line progression,n37n * where n equals the value of Pn.n37n *n37n */n37n#define _VPR_ CSI "e"n37nn37n
# /*n37n * VT - LINE TABULATIONn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * VT causes the active presentation position to be moved in the presentationn37n * component to the corresponding character position on the line atn37n * which the following line tabulation stop is set.n37n *n37n */n37n#define VT "\x0b"n37nn37n
# /*n37n * VTS - LINE TABULATION SETn37nn37n * @ Parameters Required: n37n * No Parameter Requiredn37nn37n * @ More Info:n37n * VTS causes a line tabulation stop to be set at the active line (the linen37n * that contains the active presentation position)n37n *n37n */n37n#define VTS ESC "J"n37nn37n

# %%
print(i)
print(problems)
# Out:
# 162
# [108]
